# %%
import numpy as np    
import pandas as pd

# %%
#  Load Data

df = pd.read_csv(r'E:\Test trail\Data\train_set.csv')
X = df.iloc[:, :-1].values
y = df.iloc[:,1:].values

# %%
df.head()
# Out:
#    Year  OGC                                       OG   DC               Dept  \
# 0  2015    4                         Community Health  DPH      Public Health
# 1  2013    4                         Community Health  DPH      Public Health
# 2  2015    6         General Administration & Finance  ASR  Assessor/Recorder
# 3  2016    1                        Public Protection  POL             Police
# 4  2013    2  Public Works, Transportation & Commerce  HHP   PUC Hetch Hetchy
#
#     UC                                            Union  \
# 0  250                SEIU - Health Workers, Local 1021
# 1   39                   Stationary Engineers, Local 39
# 2   21  Prof & Tech Engineers - Miscellaneous, Local 21
# 3  911                     Police Officers' Association
# 4   21  Prof & Tech Engineers - Miscellaneous, Local 21
#
#                         JF                             Job     EI  Salaries  \
# 0  Med Therapy & Auxiliary                Morgue Attendant   6725     12196
# ...

# %%
df = df.drop(['OG','Dept','Union','Job','H/D','YT'], axis=1)
df.head()
# Out:
#    Year  OGC   DC   UC                       JF     EI  Salaries  Overtime  \
# 0  2015    4  DPH  250  Med Therapy & Auxiliary   6725     12196         0
# 1  2013    4  DPH   39         Journeyman Trade  25058     74639      2820
# 2  2015    6  ASR   21     Appraisal & Taxation  46108    100554         0
# 3  2016    1  POL  911          Police Services  33369    140164     52754
# 4  2013    2  HHP   21      Information Systems  28684     58813         0
#
#    Total_Compensation
# 0               16158
# 1              115784
# 2              144708
# 3              242323
# 4               82106
